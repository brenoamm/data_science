# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics  import r2_score

#read data
data_df = pd.read_csv('data.csv')

#Define inputes and outputs
X = data_df.drop(['PE'], axis=1)
Y = data_df['PE']

#Split data into test-set and trainning set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0) #random_state = seed.

#Train the model on the trainning set
ml = LinearRegression()
ml.fit(X_train, Y_train)

#Perform Preditions
Y_pred = ml.predict(X_test)

score = r2_score(Y_test, Y_pred) #https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html
score
# Out:
# 0.929899469443679

# %%
#plt
plt.figure(figsize=(15,10))
plt.scatter(Y_test, Y_pred)
plt.xlabel('actual')
plt.ylabel('predicted')
plt.title('Actual vs. Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted')

# %%
pred_y = pd.DataFrame({'Actual':Y_test, 'Predicted':Y_pred, 'Difference': Y_test-Y_pred})
pred_y
# Out:
#       Actual   Predicted  Difference
# 4834  426.18  433.362416   -7.182416
# 1768  451.10  448.388645    2.711355
# 2819  442.87  445.886618   -3.016618
# 7779  443.70  445.991729   -2.291729
# 7065  460.59  462.811283   -2.221283
# ...      ...         ...         ...
# 6452  468.19  467.147029    1.042971
# 794   431.16  431.985950   -0.825950
# 627   454.20  456.060611   -1.860611
# 3515  444.13  446.911906   -2.781906
# 7600  436.58  432.573262    4.006738
#
# [1914 rows x 3 columns]

# %%
lines = pred_y[:10].plot.line()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(1, 10, 10)

plt.plot(x, Y_test[:10], label='real values')
plt.plot(x, Y_pred[:10], label='predicted values')
plt.title("Pred vc Real Comparison")
plt.xlabel("index")
plt.ylabel("output")

plt.legend()
